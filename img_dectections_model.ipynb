# %% [markdown]
# <a href="https://colab.research.google.com/github/Arafat69927/API/blob/main/img_dectections_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 4.7 MB/s eta 0:00:00
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 24.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 3.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolo11n.pt")

# %%
results = model.predict(
    source="/content/images (2).jpg",
    conf=0.10,
    imgsz=640,
    save=True
)
# Out:
# image 1/1 /content/images (2).jpg: 448x640 1 person, 1 dog, 439.2ms
# Speed: 15.7ms preprocess, 439.2ms inference, 40.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict

# %%
from google.colab import files
files.download('/content/images (2).jpg')

# %%
# !pip install ultralytics -q

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
results = model.predict(
    source="/content/stock-footage-road-security-camera-for-speed-pacification-installed-on-the-expressway-cloudy-day (2).webm",
    conf=0.10,
    imgsz=640,
    save=True
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/507) /content/stock-footage-road-security-camera-for-speed-pacification-installed-on-the-expressway-cloudy-day (2).webm: 384x640 1 person, 33 cars, 1 bus, 20 trucks, 4 traffic lights, 433.9ms
# video 1/1 (frame 2/507) /content/stock-footage-road-security-camera-for-speed-pacification-installed-on-the-expressway-cloudy-day (2).webm: 384x640 1 person, 33 cars, 1 bus, 18 trucks, 6 traffic lights, 139.2ms
# ...

# %%
from google.colab import files
files.download('/content/runs/detect/predict/stock-footage-road-security-camera-for-speed-pacification-installed-on-the-expressway-cloudy-day (2).avi')

# %%
# !git config --global user.name "Yeasin Arafat"
# !git config --global user.email "arafatkhan43476@gmail.com"
